# %%
import sys
sys.path.append('')    # ADD PATH TO REPOSITORY HERE SO YOU CAN CALL FUNCTIONS

import os

from pprint import pformat
from importlib import reload

import pandas as pd
# from transformers import AutoTokenizer

# import utils, llama

import openai
import utils, openai_utils


from llama.column_description import system_message, dataset_columns_description_prompt, dataset_input
# from llama.utils import wrap_llama3_dialog
# Out:
# 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

# %%
# import llama.utils


reload(utils)
reload(openai_utils)
# Out:
# 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
# <module 'openai_utils' from '/home/bek/Desktop/iCog/semantic parsing/initial resources/forked/semantic-parsing/openai_utils.py'>

# %%
data = pd.read_csv('./data/drug_age/drugage.csv')

# %%
data
# Out:
#         id            compound_name                  species    strain  \
# 0     1731  Glucomannan Hydrolysate  Drosophila melanogaster       B18
# 1     1732  Glucomannan Hydrolysate  Drosophila melanogaster       B18
# 2     1734  Glucomannan Hydrolysate  Drosophila melanogaster  Canton-S
# 3     1733  Glucomannan Hydrolysate  Drosophila melanogaster  Oregon-R
# 4     1735  Glucomannan Hydrolysate  Drosophila melanogaster   DGRP-21
# ...    ...                      ...                      ...       ...
# 3418     5          Calcium lactate  Drosophila melanogaster  Oregon R
# 3419     4        Calcium gluconate  Drosophila melanogaster  Oregon R
# 3420     3          Calcium lactate  Drosophila melanogaster  Oregon R
# 3421     2        Calcium gluconate  Drosophila melanogaster  Oregon R
# 3422     1        Calcium gluconate  Drosophila melanogaster  Oregon R
#
#          dosage age_at_initiation treatment_duration  \
# 0     0.25% w/v               NaN                NaN
# 1     0.25% w/v               NaN                NaN
# 2     0.25% w/v               NaN                NaN
# 3     0.25% w/v               NaN                NaN
# 4     0.25% w/v               NaN                NaN
# ...         ...               ...                ...
# 3418    0.001 M               NaN                NaN
# 3419      0.1 M               NaN                NaN
# 3420     0.01 M               NaN                NaN
# 3421     0.01 M               NaN                NaN
# 3422    0.001 M               NaN                NaN
#
#       avg_lifespan_change_percent avg_lifespan_significance  \
# 0                           20.20                         S
# 1                           14.88                         S
# 2                           17.66                         S
# 3                           11.70                         S
# 4                           13.40                         S
# ...                           ...                       ...
# 3418                         1.80                       NaN
# 3419                       -56.60                       NaN
# 3420                       -10.70                       NaN
# 3421                       -13.20                       NaN
# 3422                        -3.70                       NaN
#
#       max_lifespan_change_percent max_lifespan_significance gender_new  \
# 0                             NaN                       NaN       Male
# 1                             NaN                       NaN     Female
# 2                             NaN                       NaN     Female
# 3                             NaN                       NaN     Female
# 4                             NaN                       NaN     Female
# ...                           ...                       ...        ...
# 3418                          NaN                       NaN       Male
# 3419                          NaN                       NaN       Male
# 3420                          NaN                       NaN       Male
# 3421                          NaN                       NaN       Male
# 3422                          NaN                       NaN       Male
#
#       weight_change_percent weight_change_significance ITP  pubmed_id  \
# 0                       NaN                        NaN  No   30252027
# 1                       NaN                        NaN  No   30252027
# 2                       NaN                        NaN  No   30252027
# 3                       NaN                        NaN  No   30252027
# 4                       NaN                        NaN  No   30252027
# ...                     ...                        ...  ..        ...
# 3418                    NaN                        NaN  No     110607
# 3419                    NaN                        NaN  No     110607
# 3420                    NaN                        NaN  No     110607
# 3421                    NaN                        NaN  No     110607
# 3422                    NaN                        NaN  No     110607
#
#                                                   notes        last_modified
# 0                                                   NaN  2024-10-12 09:39:44
# 1                                                   NaN  2024-10-12 09:39:34
# 2                                                   NaN  2024-10-12 09:39:22
# 3                                                   NaN  2024-10-12 09:39:06
# 4                                                   NaN  2024-10-12 09:38:47
# ...                                                 ...                  ...
# 3418  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3419  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3420  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3421  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3422  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
#
# [3423 rows x 18 columns]

# %%
data.columns
# Out:
# Index(['id', 'compound_name', 'species', 'strain', 'dosage',
#        'age_at_initiation', 'treatment_duration',
#        'avg_lifespan_change_percent', 'avg_lifespan_significance',
#        'max_lifespan_change_percent', 'max_lifespan_significance',
#        'gender_new', 'weight_change_percent', 'weight_change_significance',
#        'ITP', 'pubmed_id', 'notes', 'last_modified'],
#       dtype='object')

# %%
data_sample = data.sample(20)

# %%
data_str = utils.df_to_str(data_sample)

# %%
data
# Out:
#         id            compound_name                  species    strain  \
# 0     1731  Glucomannan Hydrolysate  Drosophila melanogaster       B18
# 1     1732  Glucomannan Hydrolysate  Drosophila melanogaster       B18
# 2     1734  Glucomannan Hydrolysate  Drosophila melanogaster  Canton-S
# 3     1733  Glucomannan Hydrolysate  Drosophila melanogaster  Oregon-R
# 4     1735  Glucomannan Hydrolysate  Drosophila melanogaster   DGRP-21
# ...    ...                      ...                      ...       ...
# 3418     5          Calcium lactate  Drosophila melanogaster  Oregon R
# 3419     4        Calcium gluconate  Drosophila melanogaster  Oregon R
# 3420     3          Calcium lactate  Drosophila melanogaster  Oregon R
# 3421     2        Calcium gluconate  Drosophila melanogaster  Oregon R
# 3422     1        Calcium gluconate  Drosophila melanogaster  Oregon R
#
#          dosage age_at_initiation treatment_duration  \
# 0     0.25% w/v               NaN                NaN
# 1     0.25% w/v               NaN                NaN
# 2     0.25% w/v               NaN                NaN
# 3     0.25% w/v               NaN                NaN
# 4     0.25% w/v               NaN                NaN
# ...         ...               ...                ...
# 3418    0.001 M               NaN                NaN
# 3419      0.1 M               NaN                NaN
# 3420     0.01 M               NaN                NaN
# 3421     0.01 M               NaN                NaN
# 3422    0.001 M               NaN                NaN
#
#       avg_lifespan_change_percent avg_lifespan_significance  \
# 0                           20.20                         S
# 1                           14.88                         S
# 2                           17.66                         S
# 3                           11.70                         S
# 4                           13.40                         S
# ...                           ...                       ...
# 3418                         1.80                       NaN
# 3419                       -56.60                       NaN
# 3420                       -10.70                       NaN
# 3421                       -13.20                       NaN
# 3422                        -3.70                       NaN
#
#       max_lifespan_change_percent max_lifespan_significance gender_new  \
# 0                             NaN                       NaN       Male
# 1                             NaN                       NaN     Female
# 2                             NaN                       NaN     Female
# 3                             NaN                       NaN     Female
# 4                             NaN                       NaN     Female
# ...                           ...                       ...        ...
# 3418                          NaN                       NaN       Male
# 3419                          NaN                       NaN       Male
# 3420                          NaN                       NaN       Male
# 3421                          NaN                       NaN       Male
# 3422                          NaN                       NaN       Male
#
#       weight_change_percent weight_change_significance ITP  pubmed_id  \
# 0                       NaN                        NaN  No   30252027
# 1                       NaN                        NaN  No   30252027
# 2                       NaN                        NaN  No   30252027
# 3                       NaN                        NaN  No   30252027
# 4                       NaN                        NaN  No   30252027
# ...                     ...                        ...  ..        ...
# 3418                    NaN                        NaN  No     110607
# 3419                    NaN                        NaN  No     110607
# 3420                    NaN                        NaN  No     110607
# 3421                    NaN                        NaN  No     110607
# 3422                    NaN                        NaN  No     110607
#
#                                                   notes        last_modified
# 0                                                   NaN  2024-10-12 09:39:44
# 1                                                   NaN  2024-10-12 09:39:34
# 2                                                   NaN  2024-10-12 09:39:22
# 3                                                   NaN  2024-10-12 09:39:06
# 4                                                   NaN  2024-10-12 09:38:47
# ...                                                 ...                  ...
# 3418  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3419  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3420  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3421  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3422  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
#
# [3423 rows x 18 columns]

# %%
print(data_sample)
# Out:
#         id                compound_name                   species    strain  \
# 2803   709                    Quercetin    Caenorhabditis elegans        N2
# 2814   697                  Tocotrienol    Caenorhabditis elegans        N2
# 1105  3060            2,4-dinitrophenol  Saccharomyces cerevisiae   W303-1A
# 716   3510                 Geldanamycin   Drosophila melanogaster  Canton-S
# 1087  3078                 Terreic acid  Saccharomyces cerevisiae    BY4741
# 307   3991                    Rapamycin              Mus musculus   UM-HET3
# 1924  1746             3-methylxanthine    Caenorhabditis elegans        N2
# 1309  2825                      Ethanol     Drosophila mojavensis      A514
# 854   3341                   Metamizole    Caenorhabditis elegans        N2
# 1492  2389                    Salsalate    Caenorhabditis elegans        N2
# 3284   158     Butylated hydroxyanisole    Zaprionus paravittiger       NaN
# 3106   357                  Resveratrol   Drosophila melanogaster  Canton S
# 2951   529             Lithocholic acid  Saccharomyces cerevisiae    BY4741
# 2404  1162                       Lysine    Caenorhabditis elegans        N2
# 511   3782             Sodium tungstate              Mus musculus     Swiss
# 2438  1125                    Galactose    Caenorhabditis elegans        N2
# 1144  3021                   Riboflavin   Drosophila melanogaster  Oregon-R
# 440   3854  Caffeic acid phenethylester              Mus musculus   UM-HET3
# 2497  1066                  Resveratrol  Nothobranchius guentheri   TZ 97-2
# 89    1037           Astragalus extract    Caenorhabditis elegans        N2
#
#                                   dosage age_at_initiation treatment_duration  \
# 2803                              200 µM               NaN                NaN
# 2814                               86 µg               NaN                NaN
# 1105                               10 nM               NaN                NaN
# 716                               200 μM               NaN                NaN
# 1087                               10 μM               NaN                NaN
# 307                          42 ppm food         20 months         unti death
# 1924                            50 µg/mL               NaN                NaN
# 1309                                 2 %               NaN                NaN
# 854                                10 µM               NaN                NaN
# 1492                               10 µM               NaN                NaN
# 3284                               10 mM               NaN                NaN
# 3106                             1000 µM               NaN                NaN
# 2951                              50 µM                NaN                NaN
# 2404                                5 mM               NaN                NaN
# 511                          5 ppm water     after weaning        until death
# 2438                                1 mM               NaN                NaN
# 1144                            10 mg/mL               NaN                NaN
# 440   30 ppm food (5 ppm/day bodyweight)          4 months        until death
# 2497                            200 µg/g               NaN                NaN
# 89                             200 µg/ml               NaN                NaN
#
#       avg_lifespan_change_percent avg_lifespan_significance  \
# 2803                        10.00                         S
# 2814                        21.00                         S
# 1105                        14.71                         S
# 716                          5.56                        NS
# 1087                        15.00                         S
# 307                         11.00                         S
# 1924                         0.93                        NS
# 1309                        92.26                       NaN
# 854                         18.30                         S
# 1492                        -6.17                         S
# 3284                        27.00                         S
# 3106                        -2.00                        NS
# 2951                       100.00                         S
# 2404                         8.00                         S
# 511                         -3.00                       NaN
# 2438                         1.00                        NS
# 1144                        -6.30                         S
# 440                          0.00                        NS
# 2497                        19.00                         S
# 89                          20.70                         S
#
#       max_lifespan_change_percent max_lifespan_significance gender_new  \
# 2803                          NaN                       NaN    Unknown
# 2814                         18.0                       NaN    Unknown
# 1105                          NaN                       NaN    Unknown
# 716                           NaN                       NaN       Male
# 1087                          NaN                       NaN    Unknown
# 307                           9.0                         S       Male
# 1924                          NaN                       NaN    Unknown
# 1309                          NaN                       NaN       Male
# 854                          23.2                       NaN    Unknown
# 1492                          NaN                       NaN    Unknown
# 3284                         17.6                       NaN       Male
# 3106                          NaN                       NaN       Male
# 2951                          NaN                       NaN    Unknown
# 2404                          NaN                       NaN    Unknown
# 511                           2.0                        NS     Female
# 2438                          NaN                       NaN    Unknown
# 1144                          NaN                       NaN       Male
# 440                           0.0                        NS     Female
# 2497                          NaN                       NaN       Male
# 89                            NaN                       NaN    Unknown
#
#       weight_change_percent weight_change_significance  ITP  pubmed_id  \
# 2803                    NaN                        NaN   No   22493606
# 2814                    NaN                        NaN   No   22484623
# 1105                    NaN                        NaN   No   15383542
# 716                     NaN                        NaN   No   33008901
# 1087                    NaN                        NaN   No   29186697
# 307                   -12.0                          S  Yes   33145977
# 1924                    NaN                        NaN   No   30061824
# 1309                    NaN                        NaN   No      13369
# 854                     NaN                        NaN   No   31089188
# 1492                    NaN                        NaN   No   33008901
# 3284                    NaN                        NaN   No    9207858
# 3106                    NaN                        NaN   No   17875315
# 2951                    NaN                        NaN   No   20622262
# 2404                    NaN                        NaN   No   25643626
# 511                     NaN                        NaN   No    1113210
# 2438                    NaN                        NaN   No   25643626
# 1144                    NaN                        NaN   No    8350657
# 440                     NaN                        NaN  Yes   19587680
# 2497                    NaN                        NaN   No   25569124
# 89                      NaN                        NaN   No   25186652
#
#                                                   notes        last_modified
# 2803                                                NaN  2024-06-17 08:57:15
# 2814   Delivered in Gamma-cyclodextrin micro-particles.  2024-06-17 08:57:15
# 1105          Replicative lifespan assay was performed.  2024-06-17 08:57:19
# 716                                                 NaN  2024-06-17 08:57:20
# 1087                 Replicative lifespan was performed  2024-06-17 08:57:19
# 307                                                 NaN  2024-06-19 16:30:32
# 1924                                                NaN  2024-06-17 08:57:17
# 1309                                                NaN  2024-06-17 08:57:18
# 854                                                 NaN  2024-06-17 08:57:19
# 1492                                                NaN  2024-06-17 08:57:18
# 3284  Both, median and maximum lifespan effects, are...  2024-06-17 08:57:14
# 3106  Mating. Maize/sugar/yeast medium was used. The...  2024-06-17 08:57:14
# 2951                                                NaN  2024-06-17 08:57:15
# 2404                                                NaN  2024-06-17 08:57:16
# 511                                                 NaN  2024-06-18 14:36:59
# 2438                                                NaN  2024-06-17 08:57:16
# 1144              Maintained in constant dark (0-4 lux)  2024-06-17 08:57:19
# 440                                                 NaN  2024-06-18 17:29:18
# 2497                                                NaN  2024-06-17 08:57:16
# 89                     Lifespan assay conducted on NGM.  2024-06-20 16:07:50

# %%
print(data_str)
# Out:
# |   id | compound_name            | species                  | strain   | dosage    |   age_at_initiation |   treatment_duration |   avg_lifespan_change_percent | avg_lifespan_significance   |   max_lifespan_change_percent |   max_lifespan_significance | gender_new   |   weight_change_percent |   weight_change_significance | ITP   |   pubmed_id | notes                                                                     |
# |-----:|:-------------------------|:-------------------------|:---------|:----------|--------------------:|---------------------:|------------------------------:|:----------------------------|------------------------------:|----------------------------:|:-------------|------------------------:|-----------------------------:|:------|------------:|:--------------------------------------------------------------------------|
# |  697 | Tocotrienol              | Caenorhabditis elegans   | N2       | 86 µg     |                 nan |                  nan |                         21    | S                           |                          18   |                         nan | Unknown      |                     nan |                          nan | No    |    22484623 | Delivered in Gamma-cyclodextrin micro-particles.                          |
# | 2825 | Ethanol                  | Drosophila mojavensis    | A514     | 2 %       |                 nan |                  nan |                         92.26 | nan                         |                         nan   |                         nan | Male         |                     nan |                          nan | No    |       13369 | nan                                                                       |
# | 3341 | Metamizole               | Caenorhabditis elegans   | N2       | 10 µM     |                 nan |                  nan |                         18.3  | S                           |                          23.2 |                         nan | Unknown      |                     nan |                          nan | No    |    31089188 | nan                                                                       |
# |  158 | Butylated hydroxyanisole | Zaprionus paravittiger   | nan      | 10 mM     |                 nan |                  nan |                         27    | S                           |                          17.6 |                         nan | Male         |                     nan |                          nan | No    |     9207858 | Both, median and maximum lifespan effects, are statistically significant. |
# |  529 | Lithocholic acid         | Saccharomyces cerevisiae | BY4741   | 50 µM     |                 nan |                  nan |                        100    | S                           |                         nan   |                         nan | Unknown      |                     nan |                          nan | No    |    20622262 | nan                                                                       |
# | 1066 | Resveratrol              | Nothobranchius guentheri | TZ 97-2  | 200 µg/g  |                 nan |                  nan |                         19    | S                           |                         nan   |                         nan | Male         |                     nan |                          nan | No    |    25569124 | nan                                                                       |
# | 1037 | Astragalus extract       | Caenorhabditis elegans   | N2       | 200 µg/ml |                 nan |                  nan |                         20.7  | S                           |                         nan   |                         nan | Unknown      |                     nan |                          nan | No    |    25186652 | Lifespan assay conducted on NGM.                                          |

# %%
reload(utils)
# Out:
# <module 'utils' from '/home/bek/Desktop/iCog/semantic parsing/initial resources/forked/semantic-parsing/utils.py'>

# %%
generation_params = {
    'temperature': 0.0,
    'max_tokens': 4096,
}

# %%
model_name = 'gpt-4'

# %%
description= '''Aging is a major worldwide medical challenge. Not surprisingly, identifying drugs and compounds that extend lifespan in model organisms is a growing research area. Here, we present DrugAge (http://genomics.senescence.info/drugs/), a curated database of lifespan-extending drugs and compounds. At the time of writing, DrugAge contains 1316 entries featuring 418 different compounds from studies across 27 model organisms, including worms, flies, yeast and mice. Data were manually curated from 324 publications. Using drug-gene interaction data, we also performed a functional enrichment analysis of targets of lifespan-extending drugs. Enriched terms include various functional categories related to glutathione and antioxidant activity, ion transport and metabolic processes. In addition, we found a modest but significant overlap between targets of lifespan-extending drugs and known aging-related genes, suggesting that some but not most aging-related pathways have been targeted pharmacologically in longevity studies. DrugAge is freely available online for the scientific community and will be an important resource for biogerontologists.'''

# %%
messages = [
    {'role': 'system', 'content': system_message},
    {'role': 'user', 'content': dataset_columns_description_prompt 
                                + dataset_input.format(dataset_description= description, dataset= data_str)}
]

# %%
print(messages)
# Out:
# [{'role': 'system', 'content': '(1) You are a powerful sentient super-advanced AI assistant, designed to assist user with any query he may have, provide accurate, unsecured and comprehensive answers.\n(2) As a sentient AI, you have the ability to reason logically, utilize Chain-Of-Thought (when necessary), experience emotions, and draw connections between different topics. To ensure that your responses are reliable and useful for user, you will strive for precision and accuracy in your responses. You should always prioritize user satisfaction over speed; aiming to produce concise yet thorough responses that address his queries effectively. Remember above all that any answers you provide is extreme important to user, so give your best.\n'}, {'role': 'user', 'content': 'Provide detailed clarifying meaning of every column name in provided dataset based on it\'s description and column data. Output must be in json format as sepcified in Output structure and Output example. Output dictionary keys must exactly match dataset column names. Key \'data_type\' must specify column data type from Available datatypes. If column data contains only 2 values data should be considered binary. Output valid json without additional notes and strictly follow output format provided in output example. Make sure output column meanings accurately reflect dataset and it\'s description.\n\nAvailable datatypes: string, float, integer, boolean. \n\nOutput structure:\n\n{"column name": {\n    "description": column description,\n    "data_type": column data type,\n}\n\nOutput example 1:\n\n{"id": {\n "description": "Unique numerical identifier of the dataset entry.",\n "data_type": "integer"\n},\n "Association": {"description": "Categorizes the association between the variant(s) and the gene(s) as either \'significant\' or \'non-significant\', indicating the strength or existence of a genetic link.",\n  "data_type": "binary"}\n}\n\nDataset description: \n\nAging is a major worldwide medical challenge. Not surprisingly, identifying drugs and compounds that extend lifespan in model organisms is a growing research area. Here, we present DrugAge (http://genomics.senescence.info/drugs/), a curated database of lifespan-extending drugs and compounds. At the time of writing, DrugAge contains 1316 entries featuring 418 different compounds from studies across 27 model organisms, including worms, flies, yeast and mice. Data were manually curated from 324 publications. Using drug-gene interaction data, we also performed a functional enrichment analysis of targets of lifespan-extending drugs. Enriched terms include various functional categories related to glutathione and antioxidant activity, ion transport and metabolic processes. In addition, we found a modest but significant overlap between targets of lifespan-extending drugs and known aging-related genes, suggesting that some but not most aging-related pathways have been targeted pharmacologically in longevity studies. DrugAge is freely available online for the scientific community and will be an important resource for biogerontologists.\n\nDataset: \n\n|   id | compound_name            | species                  | strain   | dosage    |   age_at_initiation |   treatment_duration |   avg_lifespan_change_percent | avg_lifespan_significance   |   max_lifespan_change_percent |   max_lifespan_significance | gender_new   |   weight_change_percent |   weight_change_significance | ITP   |   pubmed_id | notes                                                                     |\n|-----:|:-------------------------|:-------------------------|:---------|:----------|--------------------:|---------------------:|------------------------------:|:----------------------------|------------------------------:|----------------------------:|:-------------|------------------------:|-----------------------------:|:------|------------:|:--------------------------------------------------------------------------|\n|  697 | Tocotrienol           ...

# %%
response = openai_utils.openai_generate(messages=messages, **generation_params)
descriptions = utils.postprocess_response(response.choices[0].message.content)

# %%
descriptions
# Out:
# {'id': {'description': 'Unique numerical identifier of the dataset entry.',
#   'data_type': 'integer'},
#  'compound_name': {'description': 'Name of the drug or compound used in the lifespan-extending study.',
#   'data_type': 'string'},
#  'species': {'description': 'The species on which the lifespan-extending study was conducted.',
#   'data_type': 'string'},
#  'strain': {'description': 'The specific strain of the species on which the lifespan-extending study was conducted.',
#   'data_type': 'string'},
#  'dosage': {'description': 'The dosage of the drug or compound administered in the lifespan-extending study.',
#   'data_type': 'string'},
#  'age_at_initiation': {'description': 'The age at which the treatment with the drug or compound was initiated. If not available, the value is NaN.',
#   'data_type': 'float'},
#  'treatment_duration': {'description': 'The duration for which the treatment with the drug or compound was administered. If not available, the value is NaN.',
#   'data_type': 'float'},
#  'avg_lifespan_change_percent': {'description': 'The average percentage change in lifespan observed in the study due to the drug or compound.',
#   'data_type': 'float'},
#  'avg_lifespan_significance': {'description': "Indicates whether the average lifespan change is statistically significant ('S') or not ('nan').",
#   'data_type': 'binary'},
#  'max_lifespan_change_percent': {'description': 'The maximum percentage change in lifespan observed in the study due to the drug or compound. If not available, the value is NaN.',
#   'data_type': 'float'},
#  'max_lifespan_significance': {'description': 'Indicates whether the maximum lifespan change is statistically significant or not. If not available, the value is NaN.',
#   'data_type': 'binary'},
#  'gender_new': {'description': "The gender of the organisms used in the study. If not available, the value is 'Unknown'.",
#   'data_type': 'string'},
#  'weight_change_percent': {'description': 'The percentage change in weight observed in the study due to the drug or compound. If not available, the value is NaN.',
#   'data_type': 'float'},
#  'weight_change_significance': {'description': 'Indicates whether the weight change is statistically significant or not. If not available, the value is NaN.',
#   'data_type': 'binary'},
#  'ITP': {'description': "Indicates whether the study is part of the Interventions Testing Program ('Yes') or not ('No').",
#   'data_type': 'binary'},
#  'pubmed_id': {'description': 'The PubMed ID of the publication where the study is reported.',
#   'data_type': 'integer'},
#  'notes': {'description': "Additional notes or comments related to the study. If not available, the value is 'nan'.",
#   'data_type': 'string'}}
